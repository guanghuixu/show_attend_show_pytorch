# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import argparse
import torch
import math
import time
from core.model import RUNModel
from core.utils import load_pickle
parser = argparse.ArgumentParser(description='PyTorch Attend Image Captions Model')

parser.add_argument('--data', type=str, default='./data',
                    help='location of the data corpus')
parser.add_argument('--save', type=str,  default='./models/parameters.pkl',
                    help='path to save the final model')
parser.add_argument('--val_samples', type=str,  default='./models/samples.pkl',
                    help='path to save the val samples')
parser.add_argument('--test_samples', type=str,  default='./models/samples.pkl',
                    help='path to save the all test samples')
parser.add_argument('--loss_log', type=str,  default='./models/loss.pkl',
                    help='note the best val loss')

parser.add_argument('--batch_size', type=int, default=128, metavar='N',
                    help='batch size')
parser.add_argument('--epochs', type=int, default=1,
                    help='upper epoch limit')
parser.add_argument('--embedding_size', type=int, default=512,
                    help='size of word embeddings')
parser.add_argument('--seed', type=int, default=1111,
                    help='random seed')
parser.add_argument('--hidden_dim', type=int, default=1024,
                    help='hidden_dim')
parser.add_argument('--nlayers', type=int, default=2,
                    help='number of layers')

parser.add_argument('--lr', type=float, default=1e-3,
                    help='initial learning rate')
parser.add_argument('--clip', type=float, default=0.25,
                    help='gradient clipping')
parser.add_argument('--dropout', type=float, default=0.2,
                    help='dropout applied to layers (0 = no dropout)')
args = parser.parse_args()

torch.manual_seed(args.seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(args.seed)

best_val_loss = load_pickle(args.loss_log)
model = RUNModel(args,best_val_loss)

# %%
model.test(save_sampled_captions=True,save_sampled_captions=False)
# Out:
# Loaded ./val_caption.pkl..

# %%
# Out:
# image_idxs <type 'numpy.ndarray'> (399998,) int32
# file_names <type 'numpy.ndarray'> (82783,) <U55
# word_to_idx <type 'dict'> 23110
# features <type 'numpy.ndarray'> (82783, 196, 512) float32
# captions <type 'numpy.ndarray'> (399998, 17) int32
# Elapse time: 230.03
# image_idxs <type 'numpy.ndarray'> (19589,) int32
# file_names <type 'numpy.ndarray'> (4052,) <U51
# features <type 'numpy.ndarray'> (4052, 196, 512) float32
# captions <type 'numpy.ndarray'> (19589, 17) int32
# Elapse time: 10.51

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-343319456770> in <module>()
# ----> 1 for i in a.keys()[:10]:
#       2     img_file = os.path.join('/home/xuguanghui/show-attend-and-tell-tensorflow/',i)
#       3     img = ndimage.imread(img_file)
#       4     plt.imshow(img)
#       5     plt.text(0, 1,'>>>'+a[i][0]+'\n>>>'+a[i][1] , color='black', backgroundcolor='white', fontsize=18)
#
# NameError: name 'a' is not defined
